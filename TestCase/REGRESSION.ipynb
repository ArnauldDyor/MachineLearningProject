# %% [markdown]
# # REGRESSION LINEAIRE

# %% [markdown]
# ### IMPORT

# %%
import matplotlib.pyplot as plt
import numpy as np
from CLibrary import create_linear_model, fit_regression, useTrainModel, toArray

# %% [markdown]
# ### LINEAR SIMPLE MODEL X2

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      5,
      8
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
W = create_linear_model(2)
fit_regression(W, toArray(X, 2, 1), 2, 1, toArray(Y, 1, 2))

# %% [markdown]
# #### UTILISATION

# %%
abscisse = np.array([[0], [1], [2], [3]])
ordonne = []
for abs in abscisse:
    ordonne.append(useTrainModel(abs))
    
# points initiaux
plt.scatter(X,Y)

plt.plot(abscisse, ordonne)
plt.show()

# %% [markdown]
# ### NON LINEAR SIMPLE 2D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
W = create_linear_model(2)
fit_regression(W, toArray(X, 3, 1), 3, 1, toArray(Y, 1, 3))

# %% [markdown]
# #### UTILISATION

# %%
abscisse = np.array([[0], [1], [2], [3]])
ordonne = []
for abs in abscisse:
    ordonne.append(useTrainModel(abs))
    print(ordonne[-1])
    
# points initiaux
plt.scatter(X,Y)

plt.plot(abscisse, ordonne)
plt.show()
# Out:
# 2.0
# 2.25
# 2.5
# 2.75

# %% [markdown]
# ## LINEAR SIMPLE 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      7,
      3,
      2.5
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
W = create_linear_model(3)
fit_regression(W, toArray(X, 3, 2), 3, 2, toArray(Y, 1, 3))

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(40) for b in range(40)])
Ytest = np.array([[useTrainModel(c)] for c in Xtest])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)

#modèle
ax.scatter(Xtest[:,0],Xtest[:,1],Ytest)

plt.show()
plt.clf()

# %% [markdown]
# ## LINEAR TRICKY 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINENEMENT

# %%
W = create_linear_model(3)
fit_regression(W, toArray(X, 3, 2), 3, 2, toArray(Y, 1, 3))

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(40) for b in range(40)])
Ytest = np.array([[useTrainModel(c)] for c in Xtest])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)

#modèle
ax.scatter(Xtest[:,0],Xtest[:,1],Ytest)

plt.show()
plt.clf()

# %% [markdown]
# ## NON LINEAR SIMPLE 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINENEMENT

# %%
W = create_linear_model(3)
fit_regression(W, toArray(X, 4, 2), 4, 2, toArray(Y, 1, 4))

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(20) for b in range(20)])
Ytest = np.array([[useTrainModel(c)] for c in Xtest])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)

#modèle
ax.scatter(Xtest[:,0],Xtest[:,1],Ytest)

plt.show()
plt.clf()
