# %%
# CE NOTEBOOK N'EST QU'UNE PREMICE DE NOS VERITABLES TEST CASES, JE N'AI PAS IMPORTE NOS FONCTIONS, UNIQUEMENT LES RESULTATS
# Cf le script .py pour obtenir les resultats

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
#Regression linéaire cas n ° 1
#sortie après entrainement [1, 1]
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

W = [1, 1]
points1_2 = [W[0] + W[1], W[0] * 2 + W[1]]

# %%
plt.scatter(X, Y)
plt.plot([1, 2], points1_2)
plt.show()

# %%
# Regression linéaire cas n°2
# sortie de l'entrainement [0.25, 2]

X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

W = [0.25, 2]
points1_5 = [W[0] + W[1], W[0] * 5 + W[1]]

# %%
plt.scatter(X, Y)
plt.plot([1, 5], points1_5)
plt.show()

# %%
# Regression linéaire : cas n ° 3
# sortie de l'entrainement [0.5, -1, 3.5]

X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

W = [0.5, -1, 3.5]
#calcul du plan ???

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
# afficher le plan ????
plt.show()
plt.clf()

# %%
# Regression linéaire : cas n ° 4
# sortie de l'entrainement [1, 1, -2]

X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

W = [1, 1, -2]
#calcul du plan ???

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
#afficahge plan ???
plt.show()
plt.clf()

# %%
# Regression linéaire : cas n ° 4
# impossible, dimensions matrices incorrects
