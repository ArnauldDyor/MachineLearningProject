# %% [markdown]
# # PERCEPTRON MULTICOUHE  CLASSIFICATION  -- 30 / 06 / 2019

# %% [markdown]
# ### CERTAINS CAS SONT KO ALORS QU'ILS PASSENT SUR PYCHARM ?!?!?!?! POUR L'INSTANT SE RÉFÉRER À MLP.PY

# %% [markdown]
# ### IMPORTS

# %%
import matplotlib.pyplot as plt
import numpy as np
from CLibrary import create_linear_model, perceptron_multicouche, useMLP, toArray

# %% [markdown]
# ### LINEAR SIMPLE

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 2],
      [2, 3],
      [3, 3]
])
Y = np.array([
      1,
      -1,
      -1
])

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
perceptron_multicouche('C', toArray(X, 3, 2), toArray(Y, 1, 3), 3, 2, 1, [], 100, 0.1)

# %% [markdown]
# #### UTILISATION

# %%
for i in range(10, 31):
    for j in range(20, 31):
        res = useMLP(np.array([i / 10, j / 10]))
        if (res > 0):
            plt.scatter(i / 10, j / 10, color="#46f7f2")
        else:
            plt.scatter(i / 10, j / 10, color="#fbff00")
            
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')

plt.show()
plt.clf()

# %% [markdown]
# ### LINEAR MULTIPLE

# %% [markdown]
# #### INITIALISATION

# %%
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
perceptron_multicouche('C', toArray(X, 100, 2),toArray(Y, 100, 1), 100, 2, 1, [], 100, 0.01)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(10, 30) for b in range(10, 30)])
for case in SEP:
    res = useMLP(case)
    if (res > 0):
        plt.scatter(case[0], case[1], color="#46f7f2")
    else:
        plt.scatter(case[0], case[1], color="#fbff00")

plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')

plt.show()
plt.clf()

# %% [markdown]
# ### XOR

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
perceptron_multicouche('C', toArray(X, 4, 2), toArray(Y, 1, 4), 4, 2, 1, [2], 50, 0.01)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(11) for b in range(11)])
for case in SEP:
    res = useMLP(case)
    if (res > 0):
        plt.scatter(case[0], case[1], color="#46f7f2")
    else:
        plt.scatter(case[0], case[1], color="#fbff00")

plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')

plt.show()
plt.clf()

# %% [markdown]
# ### CROSS

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
perceptron_multicouche('C', toArray(X, 500, 2), toArray(Y, 1, 500), 500, 2, 1, [4], 1000, 0.01)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useMLP(case)
    if (res < 0):
        plt.scatter(case[0], case[1], color='red')
    else:
        plt.scatter(case[0], case[1], color='blue')

plt.show()
plt.clf()

# %% [markdown]
# ### MULTI LINEAR 3 CLASSES

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
perceptron_multicouche('C', toArray(X, 500, 2), toArray(Y, 500, 3), 500, 2, 3, [], 300, 0.01)

# %%
SEP = np.array([[a / 10, b / 10] for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useMLP(case)
    if (res == 0):
        plt.scatter(case[0], case[1], color='blue')
    elif (res == 1):
        plt.scatter(case[0], case[1], color='red')
    elif (res == 2):
        plt.scatter(case[0], case[1], color='green')

plt.show()
plt.clf()

# %% [markdown]
# ## MULTI CROSS

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
#très long..
perceptron_multicouche('C', toArray(X, 1000, 2), toArray(Y, 1000, 3), 1000, 2, 3, [16, 16], 1000, 0.1)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10 ]for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useTrainModel(case)
    if(res == 0):
        plt.scatter(case[0], case[1], color='blue')
    elif(res == 1) : 
        plt.scatter(case[0], case[1], color='red')
    elif(res == 2):
        plt.scatter(case[0], case[1], color='green')

plt.show()
plt.clf()
