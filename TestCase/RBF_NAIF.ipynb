# %% [markdown]
# # RBF NAÏF 04/07/2019

# %% [markdown]
# ### IMPORTS

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from CLibrary import create_linear_model, trainNaifRbf, useNaifRbf, toArray

# %% [markdown]
# ## REGRESSION

# %% [markdown]
# ### LINEAR SIMPLE MODEL X2

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      5,
      8
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('R', toArray(X, 2, 1), toArray(Y, 1, 2), 2, 1, 1, 50)

# %% [markdown]
# #### UTILISATION

# %%
abscisse = np.array([[0], [1], [2], [3]])
ordonne = []
for abs in abscisse:
    ordonne.append(useNaifRbf(abs, X, 2, 1, 1))
    
# points initiaux
plt.scatter(X,Y)

plt.plot(abscisse, ordonne)
plt.show()

# %% [markdown]
# ### NON LINEAR SIMPLE 2D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('R', toArray(X, 3, 1), toArray(Y, 1, 3), 3, 1, 1, 50)

# %% [markdown]
# #### UTILISATION

# %%
abscisse = np.array([[0], [1], [2], [3]])
ordonne = []
for abs in abscisse:
    ordonne.append(useNaifRbf(abs, X, 3, 1, 1))
    
# points initiaux
plt.scatter(X,Y)

plt.plot(abscisse, ordonne)
plt.show()

# %% [markdown]
# ## LINEAR SIMPLE 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      7,
      3,
      2.5
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('R', toArray(X, 3, 2), toArray(Y, 1, 3), 3, 2, 1, 5)

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(40) for b in range(40)])
Ytest = np.array([[useNaifRbf(c, X, 3, 2, 1)] for c in Xtest])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], Y)

# modèle
ax.scatter(Xtest[:, 0], Xtest[:, 1], Ytest)
ax.scatter(X[:, 0], X[:, 1], Y, color="black")

plt.show()
plt.clf()

# %% [markdown]
# ## LINEAR TRICKY 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINENEMENT

# %%
trainNaifRbf('R', toArray(X, 3, 2), toArray(Y, 1, 3), 3, 2, 1, 5)

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(40) for b in range(40)])
Ytest = np.array([[useNaifRbf(c, X, 3, 2, 1)] for c in Xtest])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], Y)

# modèle
ax.scatter(Xtest[:, 0], Xtest[:, 1], Ytest)
ax.scatter(X[:, 0], X[:, 1], Y, color="black")

plt.show()
plt.clf()

# %% [markdown]
# ## NON LINEAR SIMPLE 3D

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINENEMENT

# %%
trainNaifRbf('R', toArray(X, 4, 2), toArray(Y, 1, 4), 4, 2, 1, 5)

# %% [markdown]
# #### UTILISATION

# %%
Xtest = np.array([[a / 10, b / 10] for a in range(40) for b in range(40)])
Ytest = np.array([[useNaifRbf(c, X, 4, 2, 1)] for c in Xtest])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], Y)

# modèle
ax.scatter(Xtest[:, 0], Xtest[:, 1], Ytest)
ax.scatter(X[:, 0], X[:, 1], Y, color="black")

plt.show()
plt.clf()

# %% [markdown]
# ## CLASSIFICATION

# %% [markdown]
# ### LINEAR SIMPLE

# %%
X = np.array([
      [1, 2],
      [2, 3],
      [3, 3]
])
Y = np.array([
      1,
      -1,
      -1
])

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('C', toArray(X, 3 ,2), toArray(Y, 1, 3), 3, 2, 1, 20)

# %% [markdown]
# #### UTILISATION

# %%
for i in range(10, 30):
    for j in range(10, 30):
        res = useNaifRbf(np.array([i / 10, j / 10]), X, 3, 2, 1)
        if(res > 0):
            plt.scatter(i / 10, j / 10, color="blue")
        else:
            plt.scatter(i / 10, j / 10, color="red")

plt.show()

# %% [markdown]
# ### LINEAR MULTIPLE

# %% [markdown]
# #### INITIALISATION

# %%
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='yellow')
plt.scatter(X[50:100,0], X[50:100,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('C', toArray(X, 100,2), toArray(Y, 100, 1), 100, 2, 1, 200)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(10, 30) for b in range(10, 30)])
for case in SEP:
    res = useNaifRbf(case, X, 100, 2, 1)
    if (res < 0):
        plt.scatter(case[0], case[1], color='green')
    else:
        plt.scatter(case[0], case[1], color='yellow')

plt.show()
plt.clf()

# %% [markdown]
# ### XOR

# %% [markdown]
# #### INITIALISATION

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('C', toArray(X, 4, 2), toArray(Y, 1, 4), 4, 2, 1, 10)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(10) for b in range(10)])
for case in SEP:
    res = useNaifRbf(case, X, 4, 2, 1)
    if (res < 0):
        plt.scatter(case[0], case[1], color='red')
    else:
        plt.scatter(case[0], case[1], color='blue')

plt.show()
plt.clf()

# %% [markdown]
# ### CROSS

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
 trainNaifRbf('C', toArray(X, 500, 2), toArray(Y, 1, 500), 500, 2, 1, 500)

# %%
SEP = np.array([[a / 10, b / 10] for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useNaifRbf(case, X, 500, 2, 1)
    if (res < 0):
        plt.scatter(case[0], case[1], color='red')
    else:
        plt.scatter(case[0], case[1], color='blue')

plt.show()
plt.clf()

# %% [markdown]
# ### MULTI LINEAR 3 CLASSES

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('C', toArray(X, 500, 2), toArray(Y, 500, 3), 500, 2, 3, 500)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10] for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useNaifRbf(case, X, 500, 2, 3)
    if (res == 0):
        plt.scatter(case[0], case[1], color='green')
    elif (res == 1):
        plt.scatter(case[0], case[1], color='blue')
    elif (res == 2):
        plt.scatter(case[0], case[1], color='red')

plt.show()
plt.clf()

# %% [markdown]
# ### MULTI CROSS

# %% [markdown]
# #### INITIALISATION

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# #### ENTRAINEMENT

# %%
trainNaifRbf('C', toArray(X, 1000, 2), toArray(Y, 1000, 3), 1000, 2, 3, 500)

# %% [markdown]
# #### UTILISATION

# %%
SEP = np.array([[a / 10, b / 10 ]for a in range(-10, 10) for b in range(-10, 10)])
for case in SEP:
    res = useNaifRbf(case, X, 1000, 2, 3)
    if(res == 0):
        plt.scatter(case[0], case[1], color='blue')
    elif(res == 1) : 
        plt.scatter(case[0], case[1], color='green')
    elif(res == 2):
        plt.scatter(case[0], case[1], color='red')

plt.show()
plt.clf()
